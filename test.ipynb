# %%
from selenium import webdriver
import chromedriver_autoinstaller

driver = webdriver.Chrome("/Users/ham/Code/Python/chromedriver")
driver.get("https://m.map.naver.com/")

# %% [markdown]
# # kakao map api 자동 크롤링

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
import requests; from urllib.parse import urlparse
def address_to_latitude(address):
    global lat
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization": "KakaoAK 78a23dac4d5a733b24bed6ab79cb0c4f"})
    json_obj = result.json()
    for document in json_obj['documents']:
        lat = document['y']
    return lat

def address_to_longtitude(address):
    global long
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization": "KakaoAK 78a23dac4d5a733b24bed6ab79cb0c4f"})
    json_obj = result.json()
    for document in json_obj['documents']:
         long = document['x']
    return long
# 마포 용산 강남 중구 종로구 강북구 도봉구

# petLoc = ["마포구", "용산구", "강남구", "중구", "종로구", "강북구", "도봉구"]
petLoc = ["마포구", "용산구"]
find = "동물병원"
results = []
time.sleep(10)

driver = webdriver.Chrome(
    executable_path= "/Users/ham/Code/Python/chromedriver"
)
url = "https://m.map.naver.com/"
driver.get(url)
action = ActionChains(driver)



for loc in petLoc:
    time.sleep(4)
    driver.find_element_by_class_name('Nbox_input_text').click()
    searchPetHos = loc + find
    driver.find_element_by_class_name('Nbox_input_text._search_input').send_keys(searchPetHos)
    driver.find_element_by_xpath('//*[@id="ct"]/div[1]/div[1]/form/div/div[2]/div/span[2]/button[2]').click()

    time.sleep(4)
    replys =driver.find_elements_by_xpath('//*[@id="ct"]/div[2]/ul/li')
    print(len(replys))
    #ct > div.search_listview._content._ctList > ul > li:nth-child(1) > div.item_info > div.item_info_inn > div > a
    #ct > div.search_listview._content._ctList > ul > li:nth-child(1) > div.item_info > div.item_info_inn > div > a
    #ct > div.search_listview._content._ctList > ul > li:nth-child(1) > div.item_info > a.a_item.a_item_distance._linkSiteview
    for index, reply in enumerate(replys):
            code = reply.find_element_by_css_selector('div.wrap_item > a.data-cid')
            name = reply.find_element_by_css_selector('div.item_tit').text
            address =reply.find_element_by_css_selector('div.wrap_item').text.split('\n')[1]
            latitude = address_to_latitude(address)
            longtitude = address_to_longtitude(address)
            results.append((name, address, latitude, longtitude))
            
    driver.back()

driver.close()
results
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-edc384494226> in <module>
#      29 find = "동물병원"
#      30 results = []
# ---> 31 time.sleep(10)
#      32
#      33 driver = webdriver.Chrome(
#
# KeyboardInterrupt:

# %% [markdown]
# # 구글로 하려했는뎅..ㅎㅎ

# %%
# https://www.google.com/maps/place/%EC%84%A0+%EB%8F%99%EB%AC%BC%EB%B3%91%EC%9B%90/@37.5844214,126.9677873,17z/data=!4m13!1m7!3m6!1s0x0:0x0!2zMzfCsDM1JzAzLjkiTiAxMjbCsDU4JzExLjkiRQ!3b1!8m2!3d37.5844214!4d126.9699813!3m4!1s0x357ca3c85e3bd02f:0x86aad9245eab62ad!8m2!3d37.5844214!4d126.9699813
#action-menu > ul > li:nth-child(1) > div.nbpPqf-enu-x3Eknd-text-haAclf > div.nbpPqf-menu-x3Eknd-text
#action-menu > ul > li:nth-child(1) > div.nbpPqf-menu-x3Eknd-text-haAclf > div.nbpPqf-menu-x3Eknd-text

# %% [markdown]
# # 카카오맵 지도 표시

# %%
<!-- 지도를 표시할 div -->
<div id='map' style='width:300px;height:200px;display:inline-block;'></div>
 
<script type='text/javascript' src='//dapi.kakao.com/v2/maps/sdk.js?appkey=xxxxxxxxxxxxxxxxxxxxxxxxxx'></script>
<script>
    var container = document.getElementById('map');  // 지도를 표시할 div
    var options = {
               center: new kakao.maps.LatLng(37.5166119773031, 127.041258693516),  // 지도의 중심좌표
               level: 3  // 지도 확대 레벨
    };
    // 지도를 표시할 div 와 지도 옵션으로 지도 생성
    var map = new kakao.maps.Map(container, options);
    
    // 마커생성 추가
    var markerPosition  = new kakao.maps.LatLng(37.5166119773031, 127.041258693516);
    var marker = new kakao.maps.Marker({position: markerPosition});
    marker.setMap(map);
</script>
# Out:
#   File "<ipython-input-10-b4aa60ce8676>", line 1
#     <!-- 지도를 표시할 div -->
#     ^
# SyntaxError: invalid syntax

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
import requests; from urllib.parse import urlparse
def address_to_latitude(address):
    global lat
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization": "KakaoAK 78a23dac4d5a733b24bed6ab79cb0c4f"})
    json_obj = result.json()
    for document in json_obj['documents']:
        lat = document['y']
    return lat

def address_to_longtitude(address):
    global long
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+address
    result = requests.get(urlparse(url).geturl(),
                     headers = {"Authorization": "KakaoAK 78a23dac4d5a733b24bed6ab79cb0c4f"})
    json_obj = result.json()
    for document in json_obj['documents']:
         long = document['x']
    return long
# 마포 용산 강남 중구 종로구 강북구 도봉구

petLoc = ["마포구", "용산구", "강남구", "중구", "종로구", "강북구", "도봉구"]
find = "동물병원"
results = []
time.sleep(10)

driver = webdriver.Chrome(
    executable_path= "/Users/ham/Code/Python/chromedriver"
)
url = "https://m.map.naver.com/"
driver.get(url)
action = ActionChains(driver)

for loc in petLoc:
    time.sleep(4)
    driver.find_element_by_class_name('Nbox_input_text').click()
    searchPetHos = loc + find
    driver.find_element_by_class_name('Nbox_input_text._search_input').send_keys(searchPetHos)
    driver.find_element_by_xpath('//*[@id="ct"]/div[1]/div[1]/form/div/div[2]/div/span[2]/button[2]').click()

    time.sleep(4)
    replys =driver.find_elements_by_xpath('//*[@id="ct"]/div[2]/ul/li')
    print(len(replys))
    #ct > div.search_listview._content._ctList > ul > li
    #ct > div.search_listview._content._ctList > ul > li:nth-child(1) > div.item_info > div.item_info_inn > div > a
    #ct > div.search_listview._content._ctList > ul > li:nth-child(1) > div.item_info > a.a_item.a_item_distance._linkSiteview
    for index, reply in enumerate(replys):
            code = Int(reply.get_attribute('data-id'))
            name = reply.find_element_by_css_selector('div.item_tit').text
            address =reply.find_element_by_css_selector('div.wrap_item').text.split('\n')[1]
            latitude = address_to_latitude(address)
            longtitude = address_to_longtitude(address)
            results.append((code, name, address, latitude, longtitude))
    driver.back()
    
driver.close()

results
# Out:
# 75
# 75
# 75
# 75
# 75
# 75
# 59
# [('13586909',
#   '동물메디컬센터W동물병원',
#   '서울특별시 마포구 월드컵로 46',
#   '37.5534655733354',
#   '126.912309727504'),
#  ('37371383',
#   '산들산들 동물병원동물병원',
#   '서울특별시 마포구 마포대로16길 7',
#   '37.550974625237',
#   '126.956497177398'),
#  ('31368220',
#   '캣&덴탈 하이디 동물병원동물병원',
#   '서울특별시 마포구 월드컵로3길 14 마포한강2차푸르지오 상업시설 123호',
#   '37.5510079695241',
#   '126.91164899787'),
#  ('11879134',
#   '월드펫동물종합병원동물병원',
#   '서울특별시 마포구 신촌로 248',
#   '37.5570349717626',
#   '126.953337975021'),
#  ('37620465',
#   '키다리동물병원동물병원',
#   '서울특별시 마포구 월드컵북로 218',
#   '37.5695010772358',
#   '126.904998936389'),
#  ('34581541',
#   '워너비동물병원동물병원',
#   '서울특별시 마포구 동교로 193',
#   '37.5576991224283',
#   '126.922533792965'),
#  ('1748145841',
#   '동물사랑동물병원동물병원',
#   '서울특별시 마포구 월드컵로 73 1층',
#   '37.5554229661709',
#   '126.910357684549'),
#  ('13578588',
#   '웰케어동물병원동물병원',
#   '서울특별시 마포구 월드컵북로 27 이화빌딩',
#   '37.5568752831723',
#   '126.919089470714'),
#  ('1188569390',
#   '아이웰동물병원동물병원',
# ...

# %%
# !pip install pymysql
# !pip install sqlalchemy

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine
# MySQL Connection

conn = pymysql.connect(host="127.0.0.1", user="root", passwd='qwer1234', db="dogter", charset="utf8")
curs = conn.cursor()

# %%
column = ['HospitalID', 'HospitalName', 'Location', 'Lat', 'Long']
hospitals.drop_duplicates(['HospitalID'])
hospitals= pd.DataFrame(results)

# 중복제거
hospitals.columns = column
drophospital = hospitals.drop_duplicates(['HospitalID'])

# hospitals.head()
print(drophospital)
# Out:
#      HospitalID       HospitalName                                  Location  \
# 0      13586909       동물메디컬센터W동물병원                         서울특별시 마포구 월드컵로 46
# 1      37371383      산들산들 동물병원동물병원                       서울특별시 마포구 마포대로16길 7
# 2      31368220  캣&덴탈 하이디 동물병원동물병원  서울특별시 마포구 월드컵로3길 14 마포한강2차푸르지오 상업시설 123호
# 3      11879134      월드펫동물종합병원동물병원                         서울특별시 마포구 신촌로 248
# 4      37620465        키다리동물병원동물병원                       서울특별시 마포구 월드컵북로 218
# ..          ...                ...                                       ...
# 494  1475189852         더싼동물병원동물병원                        서울특별시 노원구 동일로 1363
# 500  1679215047        브라운동물병원동물병원          서울특별시 노원구 동일로203가길 29 브라운스톤중계 1층
# 503  1465913990        웰니스동물병원동물병원                        서울특별시 노원구 마들로3길 15
# 504  1960983655        웰리스동물병원동물병원                         서울특별시 노원구 섬밭로 258
# 508    12778657       예공디자인인테리어디자인                      서울특별시 노원구 동일로242길 63
#
#                   Lat              Long
# ...

# %%
engine = create_engine("mysql+pymysql://root:qwer1234@127.0.0.1:3306/dogter?", convert_unicode=True)
conn = engine.connect()

# %%
drophospital.to_sql(name='Hospital', con=engine, if_exists='append', index=False)
